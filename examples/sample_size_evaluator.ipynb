# %%
from casual_inference.dataset import create_sample_ab_result
from casual_inference.evaluator import SampleSizeEvaluator

# %%
data = create_sample_ab_result(n_variant=2, sample_size=1000000)
data.head()
# Out:
#    rand_unit  variant  metric_bin  metric_cont
# 0          0        2           0            1
# 1          1        1           0            1
# 2          2        1           0            1
# 3          3        1           0            1
# 4          4        2           0            1

# %%
evaluator = SampleSizeEvaluator()
evaluator.evaluate(
    data=data,
    unit_col="rand_unit",
    metrics=["metric_bin", "metric_cont"]
)

# %%
evaluator.stats
# Out:
#     threshold       metric      mean       var    count  sample_size  \
# 0        0.01   metric_bin  0.102327  0.091856  1000000       5000.0
# 1        0.02   metric_bin  0.102327  0.091856  1000000      10000.0
# 2        0.03   metric_bin  0.102327  0.091856  1000000      15000.0
# 3        0.04   metric_bin  0.102327  0.091856  1000000      20000.0
# 4        0.05   metric_bin  0.102327  0.091856  1000000      25000.0
# ..        ...          ...       ...       ...      ...          ...
# 95       0.96  metric_cont  1.025987  1.025197  1000000     480000.0
# 96       0.97  metric_cont  1.025987  1.025197  1000000     485000.0
# 97       0.98  metric_cont  1.025987  1.025197  1000000     490000.0
# 98       0.99  metric_cont  1.025987  1.025197  1000000     495000.0
# 99       1.00  metric_cont  1.025987  1.025197  1000000     500000.0
#
#      mde_abs   mde_rel
# 0   0.017145  0.167548
# 1   0.012123  0.118474
# 2   0.009898  0.096734
# 3   0.008572  0.083774
# 4   0.007667  0.074930
# ..       ...       ...
# 95  0.005846  0.005698
# 96  0.005816  0.005668
# 97  0.005786  0.005639
# 98  0.005757  0.005611
# 99  0.005728  0.005583
#
# [200 rows x 8 columns]
